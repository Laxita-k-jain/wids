# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
matches=pd.read_csv("/content/drive/MyDrive/matches.csv")
matches.shape
matches.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
deliveries=pd.read_csv("/content/drive/MyDrive/deliveries.csv")
deliveries.shape
deliveries.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
deliveries= deliveries.rename(columns={'match_id': 'id'})
deliveries.head()
# Out:
#    id  inning         batting_team  ... player_dismissed  dismissal_kind  fielder
# 0   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 1   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 2   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 3   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 4   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
#
# [5 rows x 21 columns]

# %%
data = pd.merge(left=matches, right=deliveries, on='id', how='right')
data.head()
# Out:
#    id  season       city  ... player_dismissed dismissal_kind fielder
# 0   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 1   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 2   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 3   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 4   1    2017  Hyderabad  ...              NaN            NaN     NaN
#
# [5 rows x 38 columns]

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id                       0
# season                   0
# city                  1700
# date                     0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# result                   0
# dl_applied               0
# winner                 372
# win_by_runs              0
# win_by_wickets           0
# player_of_match        372
# venue                    0
# umpire1                500
# umpire2                500
# umpire3             150712
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.drop(['umpire3'],axis='columns',inplace=True)
data.drop(['dismissal_kind'],axis='columns',inplace=True)
data.drop(['fielder'],axis='columns',inplace=True)

# %%
data['date'] = pd.to_datetime(data['date'])
data['year'] = pd.DatetimeIndex(data['date']).year
data['over'] = data['over']+1
data.head()
# Out:
#    id  season       city  ... total_runs player_dismissed  year
# 0   1    2017  Hyderabad  ...          0              NaN  2017
# 1   1    2017  Hyderabad  ...          0              NaN  2017
# 2   1    2017  Hyderabad  ...          4              NaN  2017
# 3   1    2017  Hyderabad  ...          0              NaN  2017
# 4   1    2017  Hyderabad  ...          2              NaN  2017
#
# [5 rows x 36 columns]

# %%
data['inning'] = data['id'].astype(str)+(data['batting_team']).astype(str)
data.head()
# Out:
#    id  season       city  ... total_runs player_dismissed  year
# 0   1    2017  Hyderabad  ...          0              NaN  2017
# 1   1    2017  Hyderabad  ...          0              NaN  2017
# 2   1    2017  Hyderabad  ...          4              NaN  2017
# 3   1    2017  Hyderabad  ...          0              NaN  2017
# 4   1    2017  Hyderabad  ...          2              NaN  2017
#
# [5 rows x 36 columns]

# %%
data.loc[data["player_dismissed"].isnull()==True,"is_wicket"]=0
data.loc[data["player_dismissed"].isnull()==False,"is_wicket"]=1

# %%
list1 = data['inning'].unique()
(list1)
# Out:
# array(['1Sunrisers Hyderabad', '1Royal Challengers Bangalore',
#        '2Mumbai Indians', ..., '11414Chennai Super Kings',
#        '11415Mumbai Indians', '11415Chennai Super Kings'], dtype=object)

# %%
data2 = data.copy()
data2 = data2.groupby(by=['inning']).sum()['total_runs'].reset_index()
data2
# Out:
#                               inning  total_runs
# 0                100Delhi Daredevils         118
# 1                 100Kings XI Punjab          94
# 2                101Rajasthan Royals         197
# 3     101Royal Challengers Bangalore         132
# 4                 102Deccan Chargers         153
# ...                              ...         ...
# 1505              98Delhi Daredevils         194
# 1506         99Kolkata Knight Riders          67
# 1507                99Mumbai Indians          68
# 1508               9Delhi Daredevils         205
# 1509         9Rising Pune Supergiant         108
#
# [1510 rows x 2 columns]

# %%
data3 = pd.merge(left=data2, right=data, on='inning', how='right')
print(data3.shape)
data3.head()
# Out:
# (179078, 38)
#                  inning  total_runs_x  id  ...  player_dismissed  year is_wicket
# 0  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 1  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 2  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 3  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 4  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
#
# [5 rows x 38 columns]

# %%
container = pd.DataFrame()
for i in range(len(list1)):
    one_inning = data3.loc[data3['inning']==list1[i]]
    one_inning = one_inning.sort_values(['over', 'ball'], ascending=[True, True])
    one_inning = one_inning[['over','ball',
            'batsman_runs','extra_runs','total_runs_y','total_runs_x','batting_team','bowling_team','is_wicket']].reset_index(drop=True)
    one_inning['CUMSUM_runs'] = one_inning['total_runs_y'].cumsum()
    one_inning['CUMSUM_wickets'] = one_inning['is_wicket'].cumsum()


    one_inning.tail()
    frame = [container,one_inning]
    container = pd.concat(frame)
print(data3.shape)
print(container.shape)
# Out:
# (179078, 38)
# (179078, 11)

# %%
data3 = container.copy()
container.head()
# Out:
#    over  ball  batsman_runs  ...  is_wicket  CUMSUM_runs  CUMSUM_wickets
# 0     2     1             0  ...        0.0            0             0.0
# 1     2     2             0  ...        0.0            0             0.0
# 2     2     3             4  ...        0.0            4             0.0
# 3     2     4             0  ...        0.0            4             0.0
# 4     2     5             0  ...        0.0            6             0.0
#
# [5 rows x 11 columns]

# %%
featureColumns = ['over','ball',
         'batsman_runs','extra_runs','total_runs_y','CUMSUM_runs','CUMSUM_wickets','batting_team','bowling_team','is_wicket']
print(len(featureColumns))
# Out:
# 10

# %%
encoder=LabelEncoder()

# %%
data3["batting_team"]=encoder.fit_transform(data3["batting_team"])
data3["bowling_team"]=encoder.fit_transform(data3["bowling_team"])

# %%
data3.head()
# Out:
#    over  ball  batsman_runs  ...  is_wicket  CUMSUM_runs  CUMSUM_wickets
# 0     2     1             0  ...        0.0            0             0.0
# 1     2     2             0  ...        0.0            0             0.0
# 2     2     3             4  ...        0.0            4             0.0
# 3     2     4             0  ...        0.0            4             0.0
# 4     2     5             0  ...        0.0            6             0.0
#
# [5 rows x 11 columns]

# %%
data3['over_cur'] = data3['over'] + data3['ball']/10
data3 = data3[['over_cur',
               'batsman_runs','total_runs_y','CUMSUM_runs','CUMSUM_wickets','total_runs_x','batting_team','bowling_team','is_wicket']]
data3.astype(float)
data3 = data3.fillna(-99.00)
data3.isnull().values.any()
import pandas as pd
from sklearn import preprocessing
data3.head()
# Out:
#    over_cur  batsman_runs  total_runs_y  ...  batting_team  bowling_team  is_wicket
# 0       2.1             0             0  ...            14            13        0.0
# 1       2.2             0             0  ...            14            13        0.0
# 2       2.3             4             4  ...            14            13        0.0
# 3       2.4             0             0  ...            14            13        0.0
# 4       2.5             0             2  ...            14            13        0.0
#
# [5 rows x 9 columns]

# %%
def custom_accuracy(y_test,y_pred,thresold=10):
    right = 0
    l = len(y_pred)
    for i in range(0,l):
        if(abs(y_pred[i]-y_test[i]) <= thresold):
            right += 1
        else:
          print('p',y_pred[i]*300,y_test[i]*300)
    return (right)

# %%
def custom_accuracy2(y_test,y_pred,thresold):
    right = 0
    l = len(y_pred)
    for i in range(0,l):
        if(abs(y_pred[i]-y_test[i]) <= thresold):
            right += 1
    return ((right/l)*100)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X = data3.iloc[:,[0,1,2,3,4,6,7,8,]].values #Input features
y = data3.iloc[:, 5]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100,max_features=None)
model =rf.fit(X_train,y_train)
y_pred2 = rf.predict(X_test)
score = rf.score(X_test,y_test)*100
print("Score value:" , score)
# Out:
# Score value: 60.70504882101597

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()

model.add(Dense(43, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(22, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(11, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1))

model.compile(loss='mse',optimizer='adam',metrics=['RootMeanSquaredError'])

# %%
history=model.fit(x=X_train, y=y_train, epochs=50, validation_data=(X_test,y_test))
# Out:
# Epoch 1/50
# 4198/4198 [==============================] - 11s 2ms/step - loss: 5557.4697 - root_mean_squared_error: 74.5484 - val_loss: 1037.7141 - val_root_mean_squared_error: 32.2136
# Epoch 2/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 3791.3933 - root_mean_squared_error: 61.5743 - val_loss: 909.6321 - val_root_mean_squared_error: 30.1601
# Epoch 3/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 3350.4790 - root_mean_squared_error: 57.8833 - val_loss: 855.0142 - val_root_mean_squared_error: 29.2406
# Epoch 4/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 3027.5454 - root_mean_squared_error: 55.0231 - val_loss: 888.5342 - val_root_mean_squared_error: 29.8083
# Epoch 5/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2754.5164 - root_mean_squared_error: 52.4835 - val_loss: 921.6171 - val_root_mean_squared_error: 30.3581
# Epoch 6/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2645.2429 - root_mean_squared_error: 51.4319 - val_loss: 740.2913 - val_root_mean_squared_error: 27.2083
# Epoch 7/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 2503.6829 - root_mean_squared_error: 50.0368 - val_loss: 850.8911 - val_root_mean_squared_error: 29.1700
# Epoch 8/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2420.5190 - root_mean_squared_error: 49.1988 - val_loss: 778.4990 - val_root_mean_squared_error: 27.9016
# Epoch 9/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 2325.3508 - root_mean_squared_error: 48.2219 - val_loss: 782.5646 - val_root_mean_squared_error: 27.9744
# Epoch 10/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 2237.0505 - root_mean_squared_error: 47.2975 - val_loss: 781.8956 - val_root_mean_squared_error: 27.9624
# Epoch 11/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2158.7808 - root_mean_squared_error: 46.4627 - val_loss: 776.5446 - val_root_mean_squared_error: 27.8665
# Epoch 12/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 2049.1575 - root_mean_squared_error: 45.2676 - val_loss: 743.6832 - val_root_mean_squared_error: 27.2706
# Epoch 13/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 1972.4154 - root_mean_squared_error: 44.4119 - val_loss: 763.9576 - val_root_mean_squared_error: 27.6398
# Epoch 14/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1898.4941 - root_mean_squared_error: 43.5717 - val_loss: 702.9216 - val_root_mean_squared_error: 26.5127
# Epoch 15/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1831.9725 - root_mean_squared_error: 42.8015 - val_loss: 729.7586 - val_root_mean_squared_error: 27.0140
# Epoch 16/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1758.2078 - root_mean_squared_error: 41.9310 - val_loss: 725.6057 - val_root_mean_squared_error: 26.9371
# Epoch 17/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1688.5513 - root_mean_squared_error: 41.0920 - val_loss: 666.5466 - val_root_mean_squared_error: 25.8176
# Epoch 18/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1623.9058 - root_mean_squared_error: 40.2977 - val_loss: 693.5370 - val_root_mean_squared_error: 26.3351
# Epoch 19/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 1551.8309 - root_mean_squared_error: 39.3933 - val_loss: 739.7094 - val_root_mean_squared_error: 27.1976
# Epoch 20/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1487.6188 - root_mean_squared_error: 38.5697 - val_loss: 680.6353 - val_root_mean_squared_error: 26.0890
# Epoch 21/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1430.8657 - root_mean_squared_error: 37.8268 - val_loss: 690.8066 - val_root_mean_squared_error: 26.2832
# Epoch 22/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1369.6792 - root_mean_squared_error: 37.0092 - val_loss: 643.7521 - val_root_mean_squared_error: 25.3723
# Epoch 23/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 1313.6642 - root_mean_squared_error: 36.2445 - val_loss: 653.4594 - val_root_mean_squared_error: 25.5629
# Epoch 24/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1266.7000 - root_mean_squared_error: 35.5907 - val_loss: 651.7274 - val_root_mean_squared_error: 25.5290
# Epoch 25/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 1224.1689 - root_mean_squared_error: 34.9881 - val_loss: 648.2249 - val_root_mean_squared_error: 25.4603
# Epoch 26/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 1176.0076 - root_mean_squared_error: 34.2930 - val_loss: 645.5074 - val_root_mean_squared_error: 25.4068
# Epoch 27/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1133.7227 - root_mean_squared_error: 33.6708 - val_loss: 640.8140 - val_root_mean_squared_error: 25.3143
# Epoch 28/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1086.7806 - root_mean_squared_error: 32.9664 - val_loss: 627.9051 - val_root_mean_squared_error: 25.0580
# Epoch 29/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1046.0603 - root_mean_squared_error: 32.3429 - val_loss: 629.5504 - val_root_mean_squared_error: 25.0908
# Epoch 30/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1007.0118 - root_mean_squared_error: 31.7334 - val_loss: 629.1229 - val_root_mean_squared_error: 25.0823
# Epoch 31/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 979.9193 - root_mean_squared_error: 31.3037 - val_loss: 628.0870 - val_root_mean_squared_error: 25.0617
# Epoch 32/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 944.7973 - root_mean_squared_error: 30.7376 - val_loss: 630.2921 - val_root_mean_squared_error: 25.1056
# Epoch 33/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 916.5069 - root_mean_squared_error: 30.2739 - val_loss: 640.4792 - val_root_mean_squared_error: 25.3077
# Epoch 34/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 892.0038 - root_mean_squared_error: 29.8664 - val_loss: 616.5412 - val_root_mean_squared_error: 24.8302
# Epoch 35/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 871.6195 - root_mean_squared_error: 29.5232 - val_loss: 624.5596 - val_root_mean_squared_error: 24.9912
# Epoch 36/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 842.6303 - root_mean_squared_error: 29.0281 - val_loss: 628.5675 - val_root_mean_squared_error: 25.0712
# Epoch 37/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 823.4738 - root_mean_squared_error: 28.6962 - val_loss: 608.0671 - val_root_mean_squared_error: 24.6590
# Epoch 38/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 802.6587 - root_mean_squared_error: 28.3312 - val_loss: 615.4015 - val_root_mean_squared_error: 24.8073
# Epoch 39/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 783.7549 - root_mean_squared_error: 27.9956 - val_loss: 618.3427 - val_root_mean_squared_error: 24.8665
# Epoch 40/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 770.0712 - root_mean_squared_error: 27.7502 - val_loss: 611.1026 - val_root_mean_squared_error: 24.7205
# Epoch 41/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 753.8903 - root_mean_squared_error: 27.4571 - val_loss: 616.7789 - val_root_mean_squared_error: 24.8350
# Epoch 42/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 745.0801 - root_mean_squared_error: 27.2962 - val_loss: 600.3938 - val_root_mean_squared_error: 24.5029
# Epoch 43/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 735.8718 - root_mean_squared_error: 27.1270 - val_loss: 604.3510 - val_root_mean_squared_error: 24.5836
# Epoch 44/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 730.5432 - root_mean_squared_error: 27.0286 - val_loss: 613.2219 - val_root_mean_squared_error: 24.7633
# Epoch 45/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 723.8050 - root_mean_squared_error: 26.9036 - val_loss: 618.7361 - val_root_mean_squared_error: 24.8744
# Epoch 46/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 716.7773 - root_mean_squared_error: 26.7727 - val_loss: 619.6223 - val_root_mean_squared_error: 24.8922
# Epoch 47/50
# 4198/4198 [==============================] - 9s 2ms/step - loss: 711.1508 - root_mean_squared_error: 26.6674 - val_loss: 609.2316 - val_root_mean_squared_error: 24.6826
# Epoch 48/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 706.9496 - root_mean_squared_error: 26.5885 - val_loss: 619.2124 - val_root_mean_squared_error: 24.8840
# Epoch 49/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 701.9197 - root_mean_squared_error: 26.4938 - val_loss: 616.7613 - val_root_mean_squared_error: 24.8347
# Epoch 50/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 702.0613 - root_mean_squared_error: 26.4964 - val_loss: 606.7803 - val_root_mean_squared_error: 24.6329

# %%
model_losses = pd.DataFrame(model.history.history)

# %%
plt.plot(model_losses['loss'])
plt.plot(model_losses['val_loss'])
plt.legend(["loss","val_loss"])
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 18.380990108092075

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 24.63289863178157

# %%
y_test = np.asarray(y_test).astype('float32')
predictions = np.asarray(predictions).astype('float32')
print("Custom accuracy: {:.3f} %".format(custom_accuracy2(y_test,predictions,10)))
# Out:
# Custom accuracy: 38.191 %

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Actual scores')
plt.ylabel('Predicted scores')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 43)                387
#
#  dropout (Dropout)           (None, 43)                0
#
#  dense_1 (Dense)             (None, 22)                968
#
#  dropout_1 (Dropout)         (None, 22)                0
#
#  dense_2 (Dense)             (None, 11)                253
#
#  dropout_2 (Dropout)         (None, 11)                0
#
#  dense_3 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 1,620
# Trainable params: 1,620
# Non-trainable params: 0
# _________________________________________________________________
